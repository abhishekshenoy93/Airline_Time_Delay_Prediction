# %%
import numpy as np
import pandas as pd
import random as random 
from sklearn.preprocessing import LabelEncoder

# %%
data = pd.read_csv("/Users/abhishekshenoy/Downloads/1987.csv").sample(3500, random_state=44)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7046d93fd1ce> in <module>
# ----> 1 data = pd.read_csv("/Users/abhishekshenoy/Downloads/1987.csv").sample(3500, random_state=44)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
# ...

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-bd2d8857e69f> in <module>
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
#data.to_csv('1987_3500.csv')

# %%
data1 = pd.read_csv("/Users/abhishekshenoy/Downloads/1988.csv").sample(3500, random_state=44)

# %%
data1
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 4109353  1988     10          15          6   1741.0        1715   1840.0
# 466428   1988      2          19          5   1455.0        1410   1645.0
# 591153   1988      2          19          5   1510.0        1510   1532.0
# 3067454  1988      8          24          3    818.0         820   1603.0
# 2123465  1988      5          21          6    759.0         740    925.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 3325565  1988      8          24          3   1900.0        1900   2020.0
# 4395412  1988     11          22          2    731.0         720    912.0
# 68290    1988      1          30          6   1221.0        1217   1420.0
# 1048705  1988      3          17          4   1517.0        1506   1630.0
# 4864872  1988     12           7          3    719.0         705    828.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
data1.to_csv('1988_3500.csv')

# %%
data2 = pd.read_csv("/Users/abhishekshenoy/Downloads/1989.csv").sample(3500, random_state=44)

# %%
data2
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 2016510  1989      5          21          7   1714.0        1715   1823.0
# 1578173  1989      4          15          6   1815.0        1815   2016.0
# 337396   1989      1          10          2   1553.0        1552   1842.0
# 302232   1989      1          25          3   1850.0        1850   2024.0
# 4513520  1989     11           7          2    653.0         630   1247.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 2728067  1989      7          24          1   2353.0        2334     29.0
# 2067085  1989      5           3          3    809.0         805    935.0
# 3594959  1989      9           3          7   1659.0        1659   1857.0
# 1134972  1989      3           3          5   2100.0        2100   2211.0
# 3191294  1989      8          16          3   1320.0        1315   1617.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
data2.to_csv('1989_3500.csv')

# %%
data3 = pd.read_csv("/Users/abhishekshenoy/Downloads/1990.csv").sample(3500, random_state=44)

# %%
data3
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 5034223  1990     12          19          3   2054.0        2055   2105.0
# 924312   1990      3          12          1   1358.0        1330   1452.0
# 4795125  1990     11          11          7    208.0         210    710.0
# 4618763  1990     11          17          6   1330.0        1330   1445.0
# 3470384  1990      8          19          7   1925.0        1925   2045.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 4890169  1990     12           8          6   1858.0        1900   2138.0
# 11669    1990      1          30          2   1819.0        1815   1902.0
# 4631528  1990     11          28          3   2100.0        2056   2242.0
# 3073136  1990      8          26          7    759.0         800    906.0
# 4110451  1990     10          23          2      NaN        1555      NaN
#
#          CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
data3.to_csv('1990_3500.csv')

# %%
data4 = pd.read_csv("/Users/abhishekshenoy/Downloads/1991.csv").sample(3500, random_state=44)

# %%
data4
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 102504   1991      1          31          4   1711.0        1700   1740.0
# 148018   1991      1          15          2   1332.0        1335   1402.0
# 1260271  1991      4           9          2   1454.0        1325   1543.0
# 2323948  1991      6          30          7   1005.0        1004   1100.0
# 2011443  1991      5           8          3    630.0         630    803.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 2482654  1991      6          11          2    630.0         630    723.0
# 749787   1991      2          19          2   2000.0        1959   2056.0
# 2516751  1991      6           1          6   1816.0        1613   2247.0
# 2976793  1991      8           2          5   1019.0        1020   1113.0
# 3683596  1991      9          19          4   2130.0        2130   2323.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ...  TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
data4.to_csv('1991_3500.csv')

# %%
data5 = pd.read_csv("/Users/abhishekshenoy/Downloads/2001.csv", encoding='latin1').sample(3500, random_state=44)

# %%
data5
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 5715888  2001     12           5          3    843.0         840   1555.0
# 2964185  2001      6           3          7   1213.0        1210   1738.0
# 5029266  2001     10          15          1   2014.0        1740   2232.0
# 5434168  2001     11          14          3   1702.0        1705   2034.0
# 1581190  2001      4          20          5   1451.0        1450   1756.0
# ...       ...    ...         ...        ...      ...         ...      ...
# 3969438  2001      8          26          7   1147.0        1150   1449.0
# 3944250  2001      8          27          1    956.0        1000   1118.0
# 3953669  2001      8          22          3   1255.0        1300   1421.0
# 5841825  2001     12           6          4   1116.0        1130   1303.0
# 181721   2001      1          22          1   2015.0        2015   2110.0
#
#          CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# ...

# %%
data5.to_csv('2001_3500.csv')

# %%
data6 = pd.read_csv("/Users/abhishekshenoy/Desktop/Combined_21000.csv")
data6.head(100)
# Out:
#     Unnamed: 0  Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  \
# 0       422122  1987     10           4          7   1713.0        1700
# 1       351809  1987     10          15          4   1833.0        1832
# 2      1245796  1987     12           6          7    715.0         716
# 3      1111179  1987     12           9          3   1455.0        1400
# 4      1117473  1987     12          10          4   1155.0        1155
# ..         ...   ...    ...         ...        ...      ...         ...
# 95      112494  1987     10          11          7    930.0         930
# 96      297482  1987     10          26          1   2225.0        2220
# 97      306114  1987     10          18          7   1910.0        1910
# 98     1127102  1987     12          29          2    705.0         705
# 99     1120608  1987     12          22          2   1323.0        1314
#
#     ArrTime  CRSArrTime UniqueCarrier  ...  TaxiIn TaxiOut  Cancelled  \
# ...

# %%
 data6 = data6.drop(['Unnamed: 0'], axis = 1)

# %%
data6.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10           4          7   1713.0        1700   1829.0
# 1  1987     10          15          4   1833.0        1832   1936.0
# 2  1987     12           6          7    715.0         716    823.0
# 3  1987     12           9          3   1455.0        1400   1530.0
# 4  1987     12          10          4   1155.0        1155   1257.0
# 5  1987     12          12          6    620.0         620    919.0
# 6  1987     11           5          4   1429.0        1430   1516.0
# 7  1987     10          27          2    719.0         719    822.0
# 8  1987     11          12          4   1755.0        1755   2033.0
# 9  1987     11           3          2   2030.0        2015   2346.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        1820            US        631  ...    NaN      NaN          0
# 1        1944            AA        315  ...    NaN      NaN          0
# ...

# %%
data6.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
LE = LabelEncoder()

# %%
data6['Dest_encoder'] = LE.fit_transform(data6['Dest'])
data6['Org_encoder'] = LE.fit_transform(data6['Origin'])
data6['UnqCarr_encoder'] = LE.fit_transform(data6['UniqueCarrier'])

# %%
data6.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10           4          7   1713.0        1700   1829.0
# 1  1987     10          15          4   1833.0        1832   1936.0
# 2  1987     12           6          7    715.0         716    823.0
# 3  1987     12           9          3   1455.0        1400   1530.0
# 4  1987     12          10          4   1155.0        1155   1257.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... CancellationCode  Diverted  \
# 0        1820            US        631  ...              NaN         0
# 1        1944            AA        315  ...              NaN         0
# 2         833            AA       1009  ...              NaN         0
# 3        1443            CO       1636  ...              NaN         0
# 4        1250            DL         89  ...              NaN         0
#
#    CarrierDelay  WeatherDelay  NASDelay  SecurityDelay LateAircraftDelay  \
# ...

# %%
data6 = data6.drop (['Origin', 'Dest', 'TaxiIn', 'TaxiOut',
     'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
       'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay','UniqueCarrier'],axis = 1)

# %%
data6.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10           4          7   1713.0        1700   1829.0
# 1  1987     10          15          4   1833.0        1832   1936.0
# 2  1987     12           6          7    715.0         716    823.0
# 3  1987     12           9          3   1455.0        1400   1530.0
# 4  1987     12          10          4   1155.0        1155   1257.0
#
#    CRSArrTime  FlightNum TailNum  ActualElapsedTime  CRSElapsedTime  AirTime  \
# 0        1820        631     NaN               76.0              80      NaN
# 1        1944        315     NaN               63.0              72      NaN
# 2         833       1009     NaN               68.0              77      NaN
# 3        1443       1636     NaN               35.0              43      NaN
# 4        1250         89     NaN              182.0             175      NaN
#
#    ArrDelay  DepDelay  Distance  Dest_encoder  Org_encoder  UnqCarr_encoder
# ...

# %%
data6.loc[(data6['ArrDelay']>0)|(data6['DepDelay']>0), 'Delays'] = 'Y'
data6.loc[(data6['ArrDelay']<=0)&(data6['DepDelay']<=0), 'Delays'] = 'N'
data6.loc[(data6['ArrDelay']>0)|(data6['DepDelay']>0), 'DelaysN'] = '1'
data6.loc[(data6['ArrDelay']<=0)&(data6['DepDelay']<=0), 'DelaysN'] = '0'
data6.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10           4          7   1713.0        1700   1829.0
# 1  1987     10          15          4   1833.0        1832   1936.0
# 2  1987     12           6          7    715.0         716    823.0
# 3  1987     12           9          3   1455.0        1400   1530.0
# 4  1987     12          10          4   1155.0        1155   1257.0
#
#    CRSArrTime  FlightNum TailNum  ...  CRSElapsedTime  AirTime  ArrDelay  \
# 0        1820        631     NaN  ...              80      NaN       9.0
# 1        1944        315     NaN  ...              72      NaN      -8.0
# 2         833       1009     NaN  ...              77      NaN     -10.0
# 3        1443       1636     NaN  ...              43      NaN      47.0
# 4        1250         89     NaN  ...             175      NaN       7.0
#
#    DepDelay  Distance  Dest_encoder  Org_encoder  UnqCarr_encoder  Delays  \
# ...

# %%
data6.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'FlightNum', 'TailNum', 'ActualElapsedTime',
#        'CRSElapsedTime', 'AirTime', 'ArrDelay', 'DepDelay', 'Distance',
#        'Dest_encoder', 'Org_encoder', 'UnqCarr_encoder', 'Delays', 'DelaysN'],
#       dtype='object')

# %%
data6_NA = data6.drop (['DepTime','ArrDelay', 'DepDelay','FlightNum', 'TailNum','ActualElapsedTime','AirTime',
     'ArrTime', ],axis = 1)

# %%
data6.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10           4          7   1713.0        1700   1829.0
# 1  1987     10          15          4   1833.0        1832   1936.0
# 2  1987     12           6          7    715.0         716    823.0
# 3  1987     12           9          3   1455.0        1400   1530.0
# 4  1987     12          10          4   1155.0        1155   1257.0
#
#    CRSArrTime  FlightNum TailNum  ...  CRSElapsedTime  AirTime  ArrDelay  \
# 0        1820        631     NaN  ...              80      NaN       9.0
# 1        1944        315     NaN  ...              72      NaN      -8.0
# 2         833       1009     NaN  ...              77      NaN     -10.0
# 3        1443       1636     NaN  ...              43      NaN      47.0
# 4        1250         89     NaN  ...             175      NaN       7.0
#
#    DepDelay  Distance  Dest_encoder  Org_encoder  UnqCarr_encoder  Delays  \
# ...

# %%
data6 = data6.fillna(0)
data6.head(100)
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   1987     10           4          7   1713.0        1700   1829.0
# 1   1987     10          15          4   1833.0        1832   1936.0
# 2   1987     12           6          7    715.0         716    823.0
# 3   1987     12           9          3   1455.0        1400   1530.0
# 4   1987     12          10          4   1155.0        1155   1257.0
# ..   ...    ...         ...        ...      ...         ...      ...
# 95  1987     10          11          7    930.0         930    920.0
# 96  1987     10          26          1   2225.0        2220   2252.0
# 97  1987     10          18          7   1910.0        1910   2057.0
# 98  1987     12          29          2    705.0         705    929.0
# 99  1987     12          22          2   1323.0        1314   1619.0
#
#     CRSArrTime  FlightNum TailNum  ...  CRSElapsedTime  AirTime  ArrDelay  \
# ...

# %%
data6.to_csv('Combined_new_21000_clean.csv')

# %%
x = datacombined['DepDelay']

# %%
x
# Out:
# 0        11.0
# 1        -1.0
# 2        11.0
# 3        -1.0
# 4        19.0
#         ...
# 5995      9.0
# 5996     -5.0
# 5997     22.0
# 5998    144.0
# 5999      1.0
# Name: DepDelay, Length: 6000, dtype: float64

# %%
a = []

for i in x:
    #print (i)
    if i == 0:
        a.append('Y')
    else:
        a.append('N')
        
print (a)
# Out:
# ['N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'Y', 'N', 'Y', 'Y', 'N', 'Y', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'Y', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'N', 'Y', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y', 'N', 'N', 'Y
# ...

# %%
datacombined.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay'],
#       dtype='object')

# %%
datacombined['Delay'] = a

# %%
datacombined.head(10)
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  1987     10          14          3    741.0         730    912.0
# 1  1987     10          15          4    729.0         730    903.0
# 2  1987     10          17          6    741.0         730    918.0
# 3  1987     10          18          7    729.0         730    847.0
# 4  1987     10          19          1    749.0         730    922.0
# 5  1987     10          21          3    728.0         730    848.0
# 6  1987     10          22          4    728.0         730    852.0
# 7  1987     10          23          5    731.0         730    902.0
# 8  1987     10          24          6    744.0         730    908.0
# 9  1987     10          25          7    729.0         730    851.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiOut  Cancelled  \
# 0         849            PS       1451  ...     NaN          0
# 1         849            PS       1451  ...     NaN          0
# ...

# %%
datacombined.to_csv ('combined_new.csv')

# %%
datacombined['Dest'].value_counts()
# Out:
# PIT    606
# SFO    534
# LAX    372
# OAK    310
# SAN    301
#       ...
# FAI      1
# DLH      1
# CHA      1
# SRQ      1
# LAW      1
# Name: Dest, Length: 140, dtype: int64

# %%
LE = LabelEncoder()

# %%
datacombined['Dest_encoder'] = LE.fit_transform(datacombined['Dest'])

# %%
datacombined.columns
# Out:
# Index(['Year', 'Month', 'DayofMonth', 'DayOfWeek', 'DepTime', 'CRSDepTime',
#        'ArrTime', 'CRSArrTime', 'UniqueCarrier', 'FlightNum', 'TailNum',
#        'ActualElapsedTime', 'CRSElapsedTime', 'AirTime', 'ArrDelay',
#        'DepDelay', 'Origin', 'Dest', 'Distance', 'TaxiIn', 'TaxiOut',
#        'Cancelled', 'CancellationCode', 'Diverted', 'CarrierDelay',
#        'WeatherDelay', 'NASDelay', 'SecurityDelay', 'LateAircraftDelay',
#        'Delay', 'Dest_encoder'],
#       dtype='object')

# %%
datacombined.head(50)
# Out:
#     Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0   1987     10          14          3    741.0         730    912.0
# 1   1987     10          15          4    729.0         730    903.0
# 2   1987     10          17          6    741.0         730    918.0
# 3   1987     10          18          7    729.0         730    847.0
# 4   1987     10          19          1    749.0         730    922.0
# 5   1987     10          21          3    728.0         730    848.0
# 6   1987     10          22          4    728.0         730    852.0
# 7   1987     10          23          5    731.0         730    902.0
# 8   1987     10          24          6    744.0         730    908.0
# 9   1987     10          25          7    729.0         730    851.0
# 10  1987     10          26          1    735.0         730    904.0
# 11  1987     10          28          3    741.0         725    919.0
# 12  1987     10          29          4    742.0         725    906.0
# ...
