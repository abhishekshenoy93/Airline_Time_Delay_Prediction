# %%
from bs4 import BeautifulSoup as bs4
import requests
import pandas as pd

pages  = []
titles = []
urls   = []

pages_to_scrape = 5

for i in range(1,pages_to_scrape+1):
    url = ('https://www.bodybuilding.com/content/ask-the-ageless-lifter-is-it-silly-to-want-abs-after-age-40.html').format(i)
    pages.append(url)
for item in pages:
    page = requests.get(item)
    soup = bs4(page.text, 'html.parser')
   # print(soup.prettify())
    for i in soup.findAll('h3'):
        ttl=i.getText()
        titles.append(ttl)
        #print(titles)
    #for j in soup.findAll('p', class_='price_color'):
     #   price=j.getText()
      #  prices.append(price)
    #for s in soup.findAll('p', class_='star-rating'):
     #   for k,v in s.attrs.items():
      #      star =v[1]
       #     stars.append(star)
for link in soup.findALL('h3', {'class':'title'}):
    url = link.find('a').get('href') 
    urls.append(url)
    print(url)

# %%
data = {'Title':titles, url}
data
# Out:
# {'Title': ['A Light in the ...',
#   'Tipping the Velvet',
#   'Soumission',
#   'Sharp Objects',
#   'Sapiens: A Brief History ...',
#   'The Requiem Red',
#   'The Dirty Little Secrets ...',
#   'The Coming Woman: A ...',
#   'The Boys in the ...',
#   'The Black Maria',
#   'Starving Hearts (Triangular Trade ...',
#   "Shakespeare's Sonnets",
#   'Set Me Free',
#   "Scott Pilgrim's Precious Little ...",
#   'Rip it Up and ...',
#   'Our Band Could Be ...',
#   'Olio',
#   'Mesaerion: The Best Science ...',
#   'Libertarianism for Beginners',
#   "It's Only the Himalayas",
#   'In Her Wake',
#   'How Music Works',
#   'Foolproof Preserving: A Guide ...',
#   'Chase Me (Paris Nights ...',
#   'Black Dust',
#   'Birdsong: A Story in ...',
#   "America's Cradle of Quarterbacks: ...",
#   'Aladdin and His Wonderful ...',
#   'Worlds Elsewhere: Journeys Around ...',
#   'Wall and Piece',
#   'The Four Agreements: A ...',
#   'The Five Love Languages: ...',
#   'The Elephant Tree',
# ...

# %%
df=pd.DataFrame(data=data)
df.index+=1
df
# Out:
#                                   Title   Prices Stars  \
# 1                    A Light in the ...  Â£51.77  Four
# 2                    Tipping the Velvet  Â£53.74  Four
# 3                            Soumission  Â£50.10  Four
# 4                         Sharp Objects  Â£47.82  Four
# 5          Sapiens: A Brief History ...  Â£54.23  Four
# ..                                  ...      ...   ...
# 96            Lumberjanes Vol. 3: A ...  Â£19.92  Four
# 97   Layered: Baking, Building, and ...  Â£40.11  Four
# 98             Judo: Seven Steps to ...  Â£53.90  Four
# 99                                 Join  Â£35.67  Four
# 100               In the Country We ...  Â£22.00  Four
#
#                                                   URLs
# 1    http://books.toscrape.com/media/cache/2c/da/2c...
# 2    http://books.toscrape.com/media/cache/26/0c/26...
# 3    http://books.toscrape.com/media/cache/3e/ef/3e...
# 4    http://books.toscrape.com/media/cache/32/51/32...
# ...

# %%
df.to_excel("/Users/abhishekshenoy/Desktop/output.xlsx")
